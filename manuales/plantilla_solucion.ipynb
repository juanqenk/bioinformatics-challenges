# %% [markdown]
# # Solución — <TÍTULO DEL DESAFÍO>
#
# En este notebook se presenta una solución completa y comentada
# al desafío propuesto.

# %% [markdown]
# ## Recordatorio del problema
#
# Resumen breve del enunciado

# %% [markdown]
# ## Algoritmo
#
# Descripción conceptual del algoritmo, sin código aún:
#
# - Paso 1
# - Paso 2
# - Paso 3
#
# Se comenta también la complejidad temporal y espacial si procede.

# %% [markdown]
# ## Código

# %%
def funcion_principal(...):
    """
    Descripción clara de lo que hace la función.
    Parámetros:
    - ...
    Devuelve:
    - ...
    """
    ...
# Out:
#   Cell In[1], line 1
#     def funcion_principal(...):
#                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Explicación del código
#
# Explicación sección a sección:
#
# - Preprocesado de la entrada
# - Núcleo del algoritmo
# - Cálculo del resultado

# %% [markdown]
# ## Ejecución con ejemplos

# %% [markdown]
# ## Conclusión
#
# - Qué se ha aprendido
# - Qué tipo de problemas similares se pueden abordar
# - Posibles extensiones del algoritmo

# %% [markdown]
# ⬅️ [Volver al desafío](desafio.ipynb)
#
# ⬅️ [Volver al índice](../índice.md)
