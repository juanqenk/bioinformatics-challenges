# %% [markdown]
# # Desafío — <TÍTULO>
#
# En este desafío trabajarás con <breve descripción del problema>.
#
# Antes de empezar, asegúrate de haber leído el archivo `teoría.md`.

# %% [markdown]
# ## Enunciado
#
# Dado/a <descripción clara del input>, el objetivo es:
#
# - …
# - …
# - …
#
# ### Entrada
# - …
#
# ### Salida esperada
# - …

# %% [markdown]
# ## Ejemplo
#
# **Entrada**

# %% [markdown]
# **Salida**

# %% [markdown]
# ## Cuestionario

# %%
from jupyterquiz import display_quiz

display_quiz([
    {
        "question": "¿Qué nucleótidos se tienen en cuenta para el contenido GC?",
        "type": "multiple_choice",
        "answers": [
            {"answer": "G y C", "correct": True},
            {"answer": "A y T", "correct": False},
            {"answer": "A, T, G y C", "correct": False}
        ]
    }
])

# %% [markdown]
# ## Razonamiento

# %% [markdown]
# ## Celdas de trabajo

# %%
# Añade aquí tus imports y configuraciones
import sys
from pathlib import Path
# Añadir la raíz del repositorio al PYTHONPATH
repo_root = Path.cwd().parents[1]
sys.path.append(str(repo_root))

# %%
from utilidades.widgets import boton_marcar_completado

boton, salida = boton_marcar_completado()
display(boton, salida)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from utilidades.widgets import boton_marcar_completado
#       3 boton, salida = boton_marcar_completado()
#       4 display(boton, salida)
#
# ModuleNotFoundError: No module named 'utilidades'

# %% [markdown]
# ➡️ [Ver solución](solución.ipynb)
#
# ⬅️ [Volver al índice](../índice.md)
